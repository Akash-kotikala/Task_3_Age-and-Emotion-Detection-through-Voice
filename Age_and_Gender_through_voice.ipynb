mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43419559.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43419560.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43419561.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43419863.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421805.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421806.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421807.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421808.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421809.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421810.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421811.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421812.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421813.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421814.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421855.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421856.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421857.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421858.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421859.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421860.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421861.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421862.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421863.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43421864.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422034.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422035.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422036.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422037.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422038.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422039.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422040.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422041.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422042.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422043.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422044.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422045.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422046.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422047.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422048.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422049.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422050.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422051.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422052.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422053.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422054.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422055.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422056.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422057.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422058.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422059.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422060.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422061.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422062.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422063.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422064.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422065.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422066.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422067.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422068.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422069.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422070.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422071.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422072.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422073.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422074.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422075.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422076.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422077.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422078.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422079.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422080.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422081.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422082.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422083.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422084.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422085.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422086.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422087.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422088.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422089.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422090.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422091.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422092.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422098.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422099.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422100.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422101.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422102.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422103.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422104.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422105.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422106.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422107.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422113.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422114.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422115.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422116.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422117.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422138.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422139.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422140.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422141.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422142.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422143.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422144.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422145.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422146.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422147.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422148.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43422149.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425008.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425009.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425010.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425011.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425012.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425159.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425160.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425632.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425633.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425634.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425635.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425636.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425881.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425882.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425883.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425884.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43425885.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426418.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426731.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426732.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426733.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426734.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426735.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426750.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426751.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426752.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426753.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426754.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426755.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426756.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426757.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426758.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426759.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426760.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426761.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426762.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426763.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426764.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426886.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426887.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426888.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426889.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426890.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426900.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426901.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426902.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426903.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426904.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426905.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426906.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426907.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426908.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43426909.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427406.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427407.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427408.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427409.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427410.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427416.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427417.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427418.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427419.mp3
# cv-corpus-22.0-delta-2025-06-20/en/clips/common_voice_en_43427420.mp3

# %%
# Step 1 — Load metadata and inspect files (run this)
import os
import pandas as pd

BASE = "/content/cv-corpus-22.0-delta-2025-06-20/en"
TSV = os.path.join(BASE, "validated.tsv")
CLIPS_DIR = os.path.join(BASE, "clips")

print("TSV path:", TSV, "-> exists:", os.path.exists(TSV))
print("Clips dir:", CLIPS_DIR, "-> exists:", os.path.exists(CLIPS_DIR))
print()

if not os.path.exists(TSV):
    raise FileNotFoundError("validated.tsv not found in expected folder. List files with os.listdir(BASE)")

# load and preview
df = pd.read_csv(TSV, sep="\t")
print("Columns:", df.columns.tolist())
print("Total rows:", len(df))
print("\nGender value counts (including NaN):")
print(df["gender"].value_counts(dropna=False))
print("\nAge value counts (including NaN):")
print(df["age"].value_counts(dropna=False))

print("\nSample rows (path, age, gender):")
print(df[["path","age","gender"]].head(12).to_string(index=False))

# create a filtered dataframe of rows with both gender and age present
df_valid = df[df["gender"].notna() & df["age"].notna()]
print(f"\nRows with both gender & age present: {len(df_valid)}")
print(df_valid[["path","age","gender"]].head(12).to_string(index=False))
# Out:
# TSV path: /content/cv-corpus-22.0-delta-2025-06-20/en/validated.tsv -> exists: True
# Clips dir: /content/cv-corpus-22.0-delta-2025-06-20/en/clips -> exists: True
#
# Columns: ['client_id', 'path', 'sentence_id', 'sentence', 'sentence_domain', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment']
# Total rows: 170
#
# Gender value counts (including NaN):
# gender
# NaN                   82
# female_feminine       63
# male_masculine        23
# do_not_wish_to_say     2
# Name: count, dtype: int64
#
# Age value counts (including NaN):
# age
# twenties     45
# thirties     40
# NaN          32
# sixties      21
# fourties     17
# eighties      6
# fifties       6
# teens         2
# seventies     1
# Name: count, dtype: int64
#
# Sample rows (path, age, gender):
#                         path      age          gender
# common_voice_en_43199993.mp3      NaN             NaN
# common_voice_en_42736613.mp3 twenties female_feminine
# common_voice_en_42798328.mp3 thirties female_feminine
# common_voice_en_43204215.mp3      NaN             NaN
# common_voice_en_42706055.mp3 fourties             NaN
# common_voice_en_43139615.mp3 fourties             NaN
# common_voice_en_43196525.mp3      NaN             NaN
# common_voice_en_42752135.mp3 twenties female_feminine
# common_voice_en_42799557.mp3 twenties female_feminine
# common_voice_en_43193287.mp3  sixties  male_masculine
# common_voice_en_42727108.mp3 twenties             NaN
# common_voice_en_42791629.mp3      NaN female_feminine
#
# Rows with both gender & age present: 83
#                         path      age          gender
# common_voice_en_42736613.mp3 twenties female_feminine
# common_voice_en_42798328.mp3 thirties female_feminine
# common_voice_en_42752135.mp3 twenties female_feminine
# common_voice_en_42799557.mp3 twenties female_feminine
# common_voice_en_43193287.mp3  sixties  male_masculine
# common_voice_en_43200118.mp3 eighties  male_masculine
# common_voice_en_42817051.mp3 thirties female_feminine
# common_voice_en_42805882.mp3 twenties female_feminine
# common_voice_en_42751082.mp3 twenties female_feminine
# common_voice_en_42806811.mp3 twenties female_feminine
# common_voice_en_42816897.mp3 twenties female_feminine
# common_voice_en_42808952.mp3 twenties female_feminine

# %%
# Step 2 — Filter for male voices only and map ages
import numpy as np

# Keep only male voices with age present
df_male = df[(df["gender"] == "male_masculine") & df["age"].notna()].copy()
print("Total male samples with age:", len(df_male))

# Map age buckets to approximate numeric ages
age_map = {
    "teens": 15,
    "twenties": 25,
    "thirties": 35,
    "fourties": 45,
    "fifties": 55,
    "sixties": 65,
    "seventies": 75,
    "eighties": 85
}
df_male["age_num"] = df_male["age"].map(age_map)

print("\nPreview after mapping:")
print(df_male[["path","age","age_num","gender"]].head(12).to_string(index=False))

# Mark senior citizen if age_num > 60
df_male["is_senior"] = df_male["age_num"] > 60
print("\nSenior citizen counts:")
print(df_male["is_senior"].value_counts())
# Out:
# Total male samples with age: 23
#
# Preview after mapping:
#                         path      age  age_num         gender
# common_voice_en_43193287.mp3  sixties       65 male_masculine
# common_voice_en_43200118.mp3 eighties       85 male_masculine
# common_voice_en_42816075.mp3 twenties       25 male_masculine
# common_voice_en_43406505.mp3  sixties       65 male_masculine
# common_voice_en_43160566.mp3  sixties       65 male_masculine
# common_voice_en_43173951.mp3  sixties       65 male_masculine
# common_voice_en_43004194.mp3 fourties       45 male_masculine
# common_voice_en_43004225.mp3 fourties       45 male_masculine
# common_voice_en_43004302.mp3 fourties       45 male_masculine
# common_voice_en_42706159.mp3  sixties       65 male_masculine
# common_voice_en_42706160.mp3  sixties       65 male_masculine
# common_voice_en_42706169.mp3  sixties       65 male_masculine
#
# Senior citizen counts:
# is_senior
# False    13
# True     10
# Name: count, dtype: int64

# %%
# Step 3 — Extract MFCC features from male voices
import librosa
import os
from tqdm import tqdm

clips_dir = "/content/cv-corpus-22.0-delta-2025-06-20/en/clips"

X, y_age, y_senior = [], [], []

for i, row in tqdm(df_male.iterrows(), total=len(df_male)):
    file_path = os.path.join(clips_dir, row["path"])

    if not os.path.exists(file_path):
        print("⚠️ Missing file:", file_path)
        continue

    try:
        # Load audio
        signal, sr = librosa.load(file_path, sr=16000)

        # Extract MFCC (40 coefficients)
        mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=40)

        # Take mean over time axis → fixed length feature
        mfcc_mean = mfcc.mean(axis=1)

        # Save features and labels
        X.append(mfcc_mean)
        y_age.append(row["age_num"])
        y_senior.append(int(row["is_senior"]))

    except Exception as e:
        print("⚠️ Error with file:", file_path, "->", str(e))

# Convert to arrays
X = np.array(X)
y_age = np.array(y_age)
y_senior = np.array(y_senior)

print("✅ Feature extraction complete!")
print("X shape:", X.shape)
print("y_age shape:", y_age.shape)
print("y_senior shape:", y_senior.shape)
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 39.93it/s]
# ✅ Feature extraction complete!
# X shape: (23, 40)
# y_age shape: (23,)
# y_senior shape: (23,)

# %%
import os
import numpy as np
import pandas as pd
import librosa
from tqdm import tqdm
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Dataset locations
BASE = "/content/cv-corpus-22.0-delta-2025-06-20/en"
TSV = os.path.join(BASE, "validated.tsv")
CLIPS = os.path.join(BASE, "clips")

# Load and inspect
df = pd.read_csv(TSV, sep="\t")
print("Columns:", df.columns.tolist())
print("Sample rows:", df[["path", "age", "gender"]].head())

# Filter males with age info
age_map = {
    "teens": 15, "twenties": 25, "thirties": 35, "fourties": 45,
    "fifties": 55, "sixties": 65, "seventies": 75, "eighties": 85
}
df_male = df[(df["gender"] == "male_masculine") & df["age"].notna()].copy()
df_male = df_male[df_male["age"].isin(list(age_map.keys()))]
df_male["age_num"] = df_male["age"].map(age_map)
df_male["is_senior"] = df_male["age_num"] > 60

print("Total male samples w/ age:", len(df_male))
print(df_male[["path", "age", "age_num", "is_senior"]].head())
# Out:
# Columns: ['client_id', 'path', 'sentence_id', 'sentence', 'sentence_domain', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment']
# Sample rows:                            path       age           gender
# 0  common_voice_en_43199993.mp3       NaN              NaN
# 1  common_voice_en_42736613.mp3  twenties  female_feminine
# 2  common_voice_en_42798328.mp3  thirties  female_feminine
# 3  common_voice_en_43204215.mp3       NaN              NaN
# 4  common_voice_en_42706055.mp3  fourties              NaN
# Total male samples w/ age: 23
#                             path       age  age_num  is_senior
# 9   common_voice_en_43193287.mp3   sixties       65       True
# 12  common_voice_en_43200118.mp3  eighties       85       True
# 30  common_voice_en_42816075.mp3  twenties       25      False
# 52  common_voice_en_43406505.mp3   sixties       65       True
# 74  common_voice_en_43160566.mp3   sixties       65       True

# %%
def extract_mfcc(file_path, n_mfcc=40, max_len=40):
    y, sr = librosa.load(file_path, sr=16000)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc_mean = mfcc.mean(axis=1)
    if mfcc_mean.shape[0] < max_len:
        mfcc_mean = np.pad(mfcc_mean, (0, max_len - mfcc_mean.shape[0]))
    else:
        mfcc_mean = mfcc_mean[:max_len]
    return mfcc_mean.reshape((max_len,1)).astype(np.float32)

# %%
X, y_age, y_senior = [], [], []
MAX_SAMPLES = None  # Set to e.g. 20 for quick test, or None for all

for i, row in tqdm(df_male.iterrows(), total=len(df_male)):
    if MAX_SAMPLES and i >= MAX_SAMPLES:
        break
    fname = os.path.join(CLIPS, row["path"])
    if not os.path.exists(fname):
        continue
    try:
        feat = extract_mfcc(fname)
        X.append(feat)
        y_age.append(row["age_num"])
        y_senior.append(int(row["is_senior"]))
    except Exception as e:
        print("Skip:", fname, e)

X = np.array(X)
y_age = np.array(y_age)
y_senior = np.array(y_senior)

print("X shape:", X.shape, "age:", y_age.shape, "senior:", y_senior.shape)
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 23.85it/s]
# X shape: (23, 40, 1) age: (23,) senior: (23,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from sklearn.model_selection import train_test_split

# Normalize MFCC features per sample
X = X.astype("float32")
X = X / (np.max(np.abs(X), axis=1, keepdims=True) + 1e-8)

# Add channel dimension for CNN input (samples, time, features, channels)
X_cnn = np.expand_dims(X, -1)
print("CNN input shape:", X_cnn.shape)

# Train-test split
X_train, X_test, y_age_train, y_age_test, y_senior_train, y_senior_test = train_test_split(
    X_cnn, y_age, y_senior, test_size=0.2, random_state=42
)

# Build multi-task CNN model
input_shape = X_cnn.shape[1:]  # (max_len, 1, 1)

inputs = Input(shape=input_shape)

x = layers.Conv2D(32, (3,1), activation="relu", padding="same")(inputs)
x = layers.MaxPooling2D((2,1))(x)
x = layers.Conv2D(64, (3,1), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2,1))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation="relu")(x)
x = layers.Dropout(0.3)(x)

# Age regression output
age_output = layers.Dense(1, name="age_output")(x)

# Senior classification output
senior_output = layers.Dense(1, activation="sigmoid", name="senior_output")(x)

# Model
model = models.Model(inputs=inputs, outputs=[age_output, senior_output])

# Compile
model.compile(
    optimizer="adam",
    loss={
        "age_output": "mse",
        "senior_output": "binary_crossentropy"
    },
    metrics={
        "age_output": "mae",
        "senior_output": "accuracy"
    }
)

model.summary()

# Train model
history = model.fit(
    X_train,
    {"age_output": y_age_train, "senior_output": y_senior_train},
    validation_data=(X_test, {"age_output": y_age_test, "senior_output": y_senior_test}),
    epochs=30,
    batch_size=4,
    verbose=1
)

# Evaluate model performance
results = model.evaluate(
    X_test,
    {"age_output": y_age_test, "senior_output": y_senior_test},
    verbose=0
)

print(f"Age Test MAE: {results[3]:.2f} years")
print(f"Senior Detection Test Accuracy: {results[4]*100:.2f}%")
# Out:
# CNN input shape: (23, 40, 1, 1)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 40, 1, 1)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 40, 1, 32) │        128 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 20, 1, 32) │          0 │ conv2d_18[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 20, 1, 64) │      6,208 │ max_pooling2d_18… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 10, 1, 64) │          0 │ conv2d_19[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_7 (Flatten) │ (None, 640)       │          0 │ max_pooling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │     41,024 │ flatten_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64)        │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │         65 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │
30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - age_output_loss: 311.0342 - age_output_mae: 13.8963 - loss: 283.8011 - senior_output_accuracy: 0.5185 - senior_output_loss: 1.9793 - val_age_output_loss: 150.3683 - val_age_output_mae: 11.7557 - val_loss: 183.5604 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5746
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - age_output_loss: 217.7569 - age_output_mae: 12.5450 - loss: 209.0021 - senior_output_accuracy: 0.5498 - senior_output_loss: 1.8740 - val_age_output_loss: 155.5651 - val_age_output_mae: 11.9903 - val_loss: 176.6846 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5741
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - age_output_loss: 289.0264 - age_output_mae: 13.1692 - loss: 293.2004 - senior_output_accuracy: 0.5081 - senior_output_loss: 1.5231 - val_age_output_loss: 168.2661 - val_age_output_mae: 12.3251 - val_loss: 172.3737 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5791
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 376.9483 - age_output_mae: 15.4889 - loss: 376.3721 - senior_output_accuracy: 0.5532 - senior_output_loss: 2.6222 - val_age_output_loss: 199.3459 - val_age_output_mae: 12.8354 - val_loss: 177.7840 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5832
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - age_output_loss: 312.9221 - age_output_mae: 13.5619 - loss: 317.9423 - senior_output_accuracy: 0.5914 - senior_output_loss: 2.1691 - val_age_output_loss: 181.8488 - val_age_output_mae: 12.5740 - val_loss: 173.0176 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5807
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 394.2749 - age_output_mae: 15.4151 - loss: 406.5262 - senior_output_accuracy: 0.6019 - senior_output_loss: 2.2715 - val_age_output_loss: 173.2033 - val_age_output_mae: 12.4201 - val_loss: 171.8338 - val_senior_output_accuracy: 0.6000 - val_senior_output_loss: 0.5712
# Age Test MAE: 12.42 years
# Senior Detection Test Accuracy: 60.00%

# %%
import random
import librosa
import numpy as np

def augment_audio(y, sr):
    if random.random() < 0.5:
        # Pitch shift between -2 and +2 semitones
        y = librosa.effects.pitch_shift(y, sr, n_steps=random.uniform(-2, 2))
    if random.random() < 0.5:
        # Time stretch between 0.8 and 1.2 speed
        rate = random.uniform(0.8, 1.2)
        y = librosa.effects.time_stretch(y, rate)
    if random.random() < 0.5:
        # Add low-level noise
        noise = 0.005 * np.random.randn(len(y))
        y = y + noise
    return y

# %%
def extract_mfcc_seq(file_path, n_mfcc=40, max_len=40):
    y, sr = librosa.load(file_path, sr=16000)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc = mfcc[:, :max_len]
    if mfcc.shape[1] < max_len:
        mfcc = np.pad(mfcc, ((0,0), (0, max_len - mfcc.shape[1])), mode='constant')
    return mfcc.T.astype(np.float32)  # Shape: (max_len, n_mfcc)

# %%
inputs = layers.Input(shape=(40, 40, 1))

x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)

x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)

x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)

age_output = layers.Dense(1, name='age_output')(x)
senior_output = layers.Dense(1, activation='sigmoid', name='senior_output')(x)

model = tf.keras.Model(inputs=inputs, outputs=[age_output, senior_output])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

callbacks = [
    EarlyStopping(monitor='val_senior_output_accuracy', patience=10, restore_best_weights=True, mode='max'),  # <--- mode='max'
    ReduceLROnPlateau(monitor='val_senior_output_accuracy', factor=0.5, patience=5, min_lr=1e-6, mode='max')  # <--- mode='max'
]

history = model.fit(
    X_train,
    {'age_output': y_age_train, 'senior_output': y_senior_train},
    validation_data=(X_test, {'age_output': y_age_test, 'senior_output': y_senior_test}),
    epochs=100,
    batch_size=4,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - age_output_loss: 2642.6719 - age_output_mae: 49.5131 - loss: 2693.3069 - senior_output_accuracy: 0.4676 - senior_output_loss: 0.7584 - val_age_output_loss: 2060.2598 - val_age_output_mae: 48.8312 - val_loss: 2569.1792 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7027 - learning_rate: 0.0010
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - age_output_loss: 2709.4417 - age_output_mae: 50.0870 - loss: 2758.8591 - senior_output_accuracy: 0.4491 - senior_output_loss: 0.6885 - val_age_output_loss: 2050.7656 - val_age_output_mae: 48.7220 - val_loss: 2558.5142 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7086 - learning_rate: 0.0010
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 2411.5698 - age_output_mae: 46.8917 - loss: 2451.1018 - senior_output_accuracy: 0.3912 - senior_output_loss: 0.7934 - val_age_output_loss: 2041.2864 - val_age_output_mae: 48.6126 - val_loss: 2547.8577 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7172 - learning_rate: 0.0010
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - age_output_loss: 2494.5803 - age_output_mae: 47.3433 - loss: 2476.4370 - senior_output_accuracy: 0.2581 - senior_output_loss: 0.9728 - val_age_output_loss: 2031.3784 - val_age_output_mae: 48.4981 - val_loss: 2536.7124 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7267 - learning_rate: 0.0010
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 2316.0564 - age_output_mae: 45.8977 - loss: 2326.8032 - senior_output_accuracy: 0.3229 - senior_output_loss: 0.8665 - val_age_output_loss: 2020.5911 - val_age_output_mae: 48.3728 - val_loss: 2524.5549 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7366 - learning_rate: 0.0010
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - age_output_loss: 2050.7668 - age_output_mae: 42.0256 - loss: 1996.9790 - senior_output_accuracy: 0.4456 - senior_output_loss: 0.8260 - val_age_output_loss: 2010.6633 - val_age_output_mae: 48.2582 - val_loss: 2513.5366 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7391 - learning_rate: 0.0010
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - age_output_loss: 1730.3429 - age_output_mae: 39.0826 - loss: 1736.8676 - senior_output_accuracy: 0.7025 - senior_output_loss: 0.7624 - val_age_output_loss: 2002.1294 - val_age_output_mae: 48.1590 - val_loss: 2503.9961 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7405 - learning_rate: 5.0000e-04
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - age_output_loss: 1514.2695 - age_output_mae: 35.6876 - loss: 1456.4034 - senior_output_accuracy: 0.5972 - senior_output_loss: 0.7541 - val_age_output_loss: 1992.8967 - val_age_output_mae: 48.0515 - val_loss: 2493.6770 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7402 - learning_rate: 5.0000e-04
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - age_output_loss: 1426.5886 - age_output_mae: 35.3753 - loss: 1454.6421 - senior_output_accuracy: 0.3981 - senior_output_loss: 0.6655 - val_age_output_loss: 1981.1143 - val_age_output_mae: 47.9140 - val_loss: 2480.5002 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7395 - learning_rate: 5.0000e-04
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 1321.3491 - age_output_mae: 33.4398 - loss: 1350.6924 - senior_output_accuracy: 0.6863 - senior_output_loss: 0.7428 - val_age_output_loss: 1967.6725 - val_age_output_mae: 47.7574 - val_loss: 2465.6399 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7333 - learning_rate: 5.0000e-04
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - age_output_loss: 1365.7500 - age_output_mae: 34.7367 - loss: 1391.4282 - senior_output_accuracy: 0.7176 - senior_output_loss: 0.4509 - val_age_output_loss: 1950.5193 - val_age_output_mae: 47.5569 - val_loss: 2446.6934 - val_senior_output_accuracy: 0.4000 - val_senior_output_loss: 0.7197 - learning_rate: 5.0000e-04

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight('balanced', classes=np.unique(y_senior_train), y=y_senior_train)
class_weights_dict = dict(enumerate(class_weights))

history = model.fit(
    X_train, {'age_output': y_age_train, 'senior_output': y_senior_train},
    validation_data=(X_test, {'age_output': y_age_test, 'senior_output': y_senior_test}),
    epochs=100,
    batch_size=4,
    class_weight={'senior_output': class_weights_dict},
    callbacks=callbacks
)

# %%
import numpy as np
import librosa

def extract_mfcc_sequence(file_path, n_mfcc=40, max_len=40):
    """
    Extract MFCC sequence (not mean), pad or truncate to fixed length.
    Output shape: (max_len, n_mfcc)
    """
    y, sr = librosa.load(file_path, sr=16000)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    if mfcc.shape[1] < max_len:
        mfcc = np.pad(mfcc, ((0,0), (0, max_len - mfcc.shape[1])), mode='constant')
    else:
        mfcc = mfcc[:, :max_len]
    return mfcc.T.astype(np.float32)   # transpose to (time, coeff)

# %%
from tqdm import tqdm

X_seq, y_age_seq, y_senior_seq = [], [], []

MAX_SAMPLES = None  # set small for testing or None for full data

for i, row in tqdm(enumerate(df_male.itertuples()), total=len(df_male)):
    if MAX_SAMPLES and i >= MAX_SAMPLES:
        break
    file_path = os.path.join(CLIPS, row.path)
    if not os.path.exists(file_path):
        continue
    try:
        feat = extract_mfcc_sequence(file_path, max_len=40)
        X_seq.append(feat)
        y_age_seq.append(row.age_num)
        y_senior_seq.append(int(row.is_senior))
    except Exception as e:
        print(f"Skipping {file_path}: {e}")

X_seq = np.array(X_seq)  # shape (samples, time=40, n_mfcc=40)
y_age_seq = np.array(y_age_seq)
y_senior_seq = np.array(y_senior_seq)

print(f"Features shape: {X_seq.shape}, Age labels: {y_age_seq.shape}, Senior labels: {y_senior_seq.shape}")
# Out:
# 100%|██████████| 23/23 [00:01<00:00, 17.78it/s]
# Features shape: (23, 40, 40), Age labels: (23,), Senior labels: (23,)

# %%
# Add channel dimension for Conv2D input: (samples, time, coeff, 1)
X_seq = X_seq[..., np.newaxis]

# Normalize per sample
X_seq = X_seq.astype(np.float32)
X_seq /= (np.max(np.abs(X_seq), axis=(1,2,3), keepdims=True) + 1e-8)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

input_shape = X_seq.shape[1:]  # (40, 40, 1)

inputs = layers.Input(shape=input_shape)

x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)  # output: 20x20x64

x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)  # output: 10x10x128

x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2,2))(x)  # output: 5x5x256

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)

# Age regression output
age_output = layers.Dense(1, name='age_output')(x)

# Senior classification output
senior_output = layers.Dense(1, activation='sigmoid', name='senior_output')(x)

model = models.Model(inputs=inputs, outputs=[age_output, senior_output])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss={
        'age_output': 'mse',
        'senior_output': 'binary_crossentropy'
    },
    metrics={
        'age_output': ['mae'],
        'senior_output': ['accuracy']
    }
)

model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 40, 40, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 40, 40,    │        640 │ input_layer_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 20, 20,    │     73,856 │ max_pooling2d_22… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 10, 10,    │    295,168 │ max_pooling2d_23… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 5, 5, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_24… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        129 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ senior_output       │ (None, 1)         │        129 │ dropout_9[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 404,610 (1.54 MB)
#  Trainable params: 403,714 (1.54 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from sklearn.utils import class_weight
import numpy as np

# Compute class weights on training data
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_senior_train),
    y=y_senior_train
)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Create sample weights array for senior output only
sample_weights_senior = np.array([class_weight_dict[label] for label in y_senior_train], dtype=np.float32)
sample_weights_age = np.ones_like(y_age_train, dtype=np.float32)

sample_weights = {
    'age_output': sample_weights_age,
    'senior_output': sample_weights_senior
}

# %%
# Verify model output names
print("Model outputs:", model.output_names)

# Define sample weights properly to avoid errors
sample_weights = {
    'age_output': np.ones_like(y_age_train, dtype=np.float32),
    'senior_output': np.array([class_weight_dict[label] for label in y_senior_train], dtype=np.float32)
}

# Use callbacks as defined earlier (with EarlyStopping, ReduceLROnPlateau)
history = model.fit(
    X_train,
    {'age_output': y_age_train, 'senior_output': y_senior_train},
    validation_data=(X_val, {'age_output': y_age_val, 'senior_output': y_senior_val}),
    sample_weight=sample_weights,
    epochs=100,
    batch_size=4,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Model outputs: ListWrapper(['age_output', 'senior_output'])
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3315641058.py in <cell line: 0>()
#       9
#      10 # Use callbacks as defined earlier (with EarlyStopping, ReduceLROnPlateau)
# ---> 11 history = model.fit(
#      12     X_train,
#      13     {'age_output': y_age_train, 'senior_output': y_senior_train},
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in multi_step_on_iterator(iterator)
#     130         def multi_step_on_iterator(iterator):
#     131             if self.steps_per_execution == 1:
# --> 132                 return tf.experimental.Optional.from_value(
#     133                     one_step_on_data(iterator.get_next())
#     134                 )
#
# ValueError: Attr 'Toutput_types' of 'OptionalFromValue' Op passed list of length 0 less than minimum 1.
